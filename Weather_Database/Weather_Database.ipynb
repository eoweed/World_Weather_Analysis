# %% [markdown]
# # Part 1: Generate Weather Data with API Call
# # ----------------------------------------------------------------

# %% [markdown]
# ### Create set of 2,000 random coordinates

# %%
# Import the dependencies.
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# assign the arrays to variables so we can access them later
# zip the variables together so they are paired

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get nearest cities using citipy module

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
cities
# Out:
# ['narrabri',
#  'rawson',
#  'pizarro',
#  'ilhabela',
#  'ushuaia',
#  'avera',
#  'khatanga',
#  'ploemeur',
#  'richards bay',
#  'adrar',
#  'bethel',
#  'hofn',
#  'jamestown',
#  'longyearbyen',
#  'port elizabeth',
#  'ribeira grande',
#  'la palma',
#  'rikitea',
#  'bredasdorp',
#  'bengkulu',
#  'samusu',
#  'saint-philippe',
#  'albany',
#  'tubuala',
#  'idaho falls',
#  'verona',
#  'barrow',
#  'caravelas',
#  'raton',
#  'oktyabrskoye',
#  'kungurtug',
#  'huntsville',
#  'louisbourg',
#  'aksu',
#  'ostrovnoy',
#  'airai',
#  'plettenberg bay',
#  'port hardy',
#  'rio cuarto',
#  'sentyabrskiy',
#  'mindelo',
#  'chokurdakh',
#  'meyungs',
#  'tukrah',
#  'mataura',
#  'atuona',
#  'karera',
#  'pochutla',
#  'mapiripan',
#  'hilo',
#  'birjand',
#  'puerto ayora',
#  'alofi',
#  'hobyo',
#  'tulagi',
#  'northam',
#  'dzhusaly',
#  'muros',
#  'havelock',
#  'olinda',
#  'port blair',
#  'vao',
#  'sikonge',
#  'lorengau',
#  'balkhash',
#  'punta arenas',
#  'cape town',
#  'cherskiy',
#  'port lincoln',
#  'kahului',
#  'palabuhanratu',
#  'bambous virieux',
#  'vaini',
#  'merauke',
#  'yar-sale',
#  'sao filipe',
#  'digby',
#  'hermanus',
#  'asyut',
#  'deputatskiy',
#  'san cristobal',
#  'bluff',
#  'matara',
#  'suamico',
#  'taolanaro',
#  'bonfim',
#  'tura',
#  'tommot',
#  'thompson',
#  'karaul',
#  'tianpeng',
#  'nanortalik',
#  'san jose',
#  'casino',
#  'klaksvik',
#  'chuy',
#  'hithadhoo',
#  'aleksandrov gay',
#  'kralendijk',
#  'margate',
#  'palaikastron',
#  'port alfred',
#  'wadi maliz',
#  'haines junction',
#  'castro',
#  'tessalit',
#  'toliary',
#  'turbat',
#  'tandarei',
#  'kaitangata',
#  'qaanaaq',
#  'horadiz',
#  'hobart',
#  'tuktoyaktuk',
#  'kodiak',
#  'jinchengjiang',
#  'cabo san lucas',
#  'saint george',
#  'yellowknife',
#  'hami',
#  'jafarpur',
#  'busselton',
#  'taoudenni',
#  'grand baie',
#  'attawapiskat',
#  'ulladulla',
#  'srednekolymsk',
#  'natal',
#  'okha',
#  'corinto',
#  'chunskiy',
#  'tsihombe',
#  'saryshagan',
#  'sabya',
#  'douglas',
#  'kapaa',
#  'port townsend',
#  'puerto rico',
#  'tomatlan',
#  'belushya guba',
#  'tiksi',
#  'takoradi',
#  'goure',
#  'dikson',
#  'saldanha',
#  'sungaipenuh',
#  'rio grande',
#  'charters towers',
#  'det udom',
#  'punta de piedra',
#  'narsaq',
#  'zhigansk',
#  'ous',
#  'asientos',
#  'zhongshu',
#  'avarua',
#  'nabire',
#  'beringovskiy',
#  'tuatapere',
#  'butaritari',
#  'saint anthony',
#  'inongo',
#  'codrington',
#  'karratha',
#  'krasnoarmeysk',
#  'luderitz',
#  'kavieng',
#  'mayskiy',
#  'salalah',
#  'dingle',
#  'aguachica',
#  'flinders',
#  'columbus',
#  'georgetown',
#  'kosonsoy',
#  'carnarvon',
#  'fort nelson',
#  'akonolinga',
#  'cidreira',
#  'illoqqortoormiut',
#  'banda aceh',
#  'warmbad',
#  'the valley',
#  'nizhneyansk',
#  'krasnoselkup',
#  'porto murtinho',
#  'ngukurr',
#  'acarau',
#  'pevek',
#  'san pedro',
#  'los llanos de aridane',
#  'mahebourg',
#  'ardmore',
#  'sioux lookout',
#  'bogovarovo',
#  'upernavik',
#  'baraboo',
#  'bonthe',
#  'verkhnevilyuysk',
#  'comodoro rivadavia',
#  'trelew',
#  'arraial do cabo',
#  'barentsburg',
#  'necochea',
#  'torbay',
#  'clyde river',
#  'kamenka',
#  'skalistyy',
#  'mar del plata',
#  'nizhniy kuranakh',
#  'anadyr',
#  'joshimath',
#  'gat',
#  'hasaki',
#  'krapivinskiy',
#  'lavrentiya',
#  'tambopata',
#  'viligili',
#  'netivot',
#  'tazovskiy',
#  'kavaratti',
#  'cockburn harbour',
#  'umzimvubu',
#  'ilulissat',
#  'pasni',
#  'west wendover',
#  'constitucion',
#  'mancio lima',
#  'nantucket',
#  'lahij',
#  'salamiyah',
#  'narasannapeta',
#  'hannan',
#  'mecca',
#  'cazaje',
#  'witney',
#  'yenagoa',
#  'zheleznodorozhnyy',
#  'kyabram',
#  'coquimbo',
#  'tuggurt',
#  'mayo',
#  'norman wells',
#  'kropotkin',
#  'riyadh',
#  'birao',
#  'aguimes',
#  'kedougou',
#  'talnakh',
#  'fortuna',
#  'souillac',
#  'awjilah',
#  'phan rang',
#  'vila franca do campo',
#  'ponta do sol',
#  'port moresby',
#  'wanning',
#  'marzuq',
#  'moengo',
#  'ust-nera',
#  'bridgetown',
#  'kodinsk',
#  'mannarakkat',
#  'el tigre',
#  'luba',
#  'port hedland',
#  'strezhevoy',
#  'kupang',
#  'iquitos',
#  'shkotovo-26',
#  'leninskoye',
#  'akyab',
#  'cayenne',
#  'falealupo',
#  'kegayli',
#  'oistins',
#  'aklavik',
#  'santiago del estero',
#  'dezful',
#  'kuruman',
#  'portland',
#  'faanui',
#  'montego bay',
#  'muravlenko',
#  'nhulunbuy',
#  'saskylakh',
#  'nuevo progreso',
#  'sisimiut',
#  'mys shmidta',
#  'north bend',
#  'veseloyarsk',
#  'paoua',
#  'nikolskoye',
#  'pisco',
#  'mantua',
#  'graciano sanchez',
#  'huaidian',
#  'komsomolskiy',
#  'wencheng',
#  'tasiilaq',
#  'new castle',
#  'khromtau',
#  'darhan',
#  'priiskovyy',
#  'arinos',
#  'diffa',
#  'yulara',
#  'sailana',
#  'fairbanks',
#  'luena',
#  'santa isabel do rio negro',
#  'guerrero negro',
#  'lagoa',
#  'bud',
#  'new delhi',
#  'leningradskiy',
#  'susanville',
#  'gunjur',
#  'ambilobe',
#  'makokou',
#  'galiwinku',
#  'ukiah',
#  'padang',
#  'touros',
#  'zaozerne',
#  'muli',
#  'toora-khem',
#  'ocampo',
#  'new norfolk',
#  'lixourion',
#  'muswellbrook',
#  'lebu',
#  'karoi',
#  'tigil',
#  'pendleton',
#  'mount isa',
#  'dwarka',
#  'lazaro cardenas',
#  'iqaluit',
#  'gabu',
#  'walvis bay',
#  'dibaya',
#  'batagay',
#  'kushima',
#  'andenes',
#  'tir pol',
#  'kinablangan',
#  'bambanglipuro',
#  'mizque',
#  'kruisfontein',
#  'southbridge',
#  'kedrovyy',
#  'shieli',
#  'vanimo',
#  'brae',
#  'lompoc',
#  'victoria',
#  'lalmohan',
#  'turayf',
#  'dapaong',
#  'songjianghe',
#  'ancud',
#  'lafia',
#  'vaitupu',
#  'linqing',
#  'yanchukan',
#  'ranong',
#  'chongoyape',
#  'khor',
#  'auki',
#  'constantine',
#  'namatanai',
#  'hurricane',
#  'soe',
#  'havoysund',
#  'barcelos',
#  'evensk',
#  'sarangani',
#  'udgir',
#  'ponta delgada',
#  'quang ngai',
#  'shenjiamen',
#  'alvdal',
#  'maltahohe',
#  'mwene-ditu',
#  'camopi',
#  'hovd',
#  'gushikawa',
#  'pala',
#  'marcona',
#  'baymak',
#  'santa cruz',
#  'shevchenkove',
#  'xining',
#  'severo-kurilsk',
#  'kota bahru',
#  'santa maria',
#  'naze',
#  'kamaishi',
#  'black river',
#  'henties bay',
#  'kolosovka',
#  'yichang',
#  'coruripe',
#  'opuwo',
#  'santa fe',
#  'lalomanu',
#  'alasehir',
#  'tagab',
#  'suileng',
#  'makakilo city',
#  'burgeo',
#  'aykhal',
#  'belawan',
#  'esperance',
#  'sharanga',
#  'coari',
#  'sambava',
#  'grand gaube',
#  'garissa',
#  'provideniya',
#  'uvalde',
#  'esna',
#  'laguna',
#  'bealanana',
#  'tumannyy',
#  'artyk',
#  'salinas',
#  'half moon bay',
#  'sosnovo-ozerskoye',
#  'tovuz',
#  'namanga',
#  'berbera',
#  'olafsvik',
#  'rocha',
#  'iranshahr',
#  'linhares',
#  'monroe',
#  'bonavista',
#  'college',
#  'holme',
#  'mrirt',
#  'kosh-agach',
#  'sakakah',
#  'varberg',
#  'dong hoi',
#  'luebo',
#  'maceio',
#  'argir',
#  'nyurba',
#  'svetlogorsk',
#  'karasburg',
#  'ust-tsilma',
#  'halalo',
#  'ayan',
#  'aiyira',
#  'tambul',
#  'saint-paul',
#  'berlevag',
#  'meulaboh',
#  'pacific grove',
#  'kuche',
#  'ballina',
#  'ullapool',
#  'ariquemes',
#  'kloulklubed',
#  'kokopo',
#  'east london',
#  'boende',
#  'faya',
#  'la ronge',
#  'labuhan',
#  'bat khela',
#  'raudeberg',
#  'neyshabur',
#  'esmeraldas',
#  'praya',
#  'sorland',
#  'nicolas bravo',
#  'acapulco',
#  'shimoda',
#  'sorvag',
#  'tsienyane',
#  'mentok',
#  'bayshore gardens',
#  'mildura',
#  'vardo',
#  'maun',
#  'ondjiva',
#  'teguise',
#  'amderma',
#  'olean',
#  'taraz',
#  'kuryk',
#  'mackay',
#  'brigantine',
#  'geraldton',
#  'panzhihua',
#  'bathsheba',
#  'cervo',
#  'brownfield',
#  'rosarito',
#  'arlit',
#  'ducheng',
#  'dakar',
#  'herat',
#  'chittaurgarh',
#  'donskoye',
#  'santo tomas',
#  'thinadhoo',
#  'korla',
#  'husavik',
#  'fevralsk',
#  'yatou',
#  'campiglia marittima',
#  'baykit',
#  'khonsa',
#  'arona',
#  'panlaitan',
#  'belmonte',
#  'sorong',
#  'sitka',
#  'rock sound',
#  'bay roberts',
#  'matagami',
#  'tautira',
#  'grindavik',
#  'can tho',
#  'egvekinot',
#  'shubarkuduk',
#  'meadow lake',
#  'binga',
#  'rockland',
#  'warqla',
#  'domoni',
#  'carauari',
#  'asau',
#  'pangnirtung',
#  'trojan',
#  'watsa',
#  'ngunguru',
#  'tawnat',
#  'stutterheim',
#  'hwange',
#  'mangaratiba',
#  'saleaula',
#  'karlshamn',
#  'san patricio',
#  'impfondo',
#  'hvide sande',
#  'akdepe',
#  'kapit',
#  'kyren',
#  'biograd na moru',
#  'yurla',
#  'hammerfest',
#  'kalabo',
#  'bandarbeyla',
#  'ahuimanu',
#  'ewa beach',
#  'basco',
#  'lynn haven',
#  'hamilton',
#  'ahipara',
#  'ushtobe',
#  'port-cartier',
#  'doha',
#  'coracora',
#  'saint-joseph',
#  'sarankhola',
#  'bakchar',
#  'borzya',
#  'bertoua',
#  'manacapuru',
#  'puerto varas',
#  'yeppoon',
#  'mocuba',
#  'bulgan',
#  'buala',
#  'lexington',
#  'los lunas',
#  'hambantota',
#  'ulkan',
#  'maumere',
#  'eureka',
#  'yazman',
#  'vila velha',
#  'lunglei',
#  'mocambique',
#  'sao joao da barra',
#  'vestmannaeyjar',
#  'nizhniy odes',
#  'kohima',
#  'itamaraca',
#  'mountain home',
#  'hauterive',
#  'ribas do rio pardo',
#  'chengde',
#  'nampula',
#  'araouane',
#  'kudahuvadhoo',
#  'kitimat',
#  'mnogovershinnyy',
#  'toamasina',
#  'babino',
#  'beaverlodge',
#  'vostok',
#  'ternuvate',
#  'cap malheureux',
#  'najran',
#  'tibati',
#  'isangel',
#  'bara',
#  'tarazona',
#  'dalby',
#  'aflu',
#  'marfino',
#  'nizhniy ingash',
#  'lure',
#  'marsa matruh',
#  'coihaique',
#  'banganapalle',
#  'samarai',
#  'severnoye',
#  'kharp',
#  'itarema',
#  'altamira',
#  'alotau',
#  'dongsheng',
#  'cento',
#  'broome',
#  'grand river south east',
#  'katsuura',
#  'utiroa',
#  'brownsville',
#  'urubicha',
#  'megion',
#  'shirokiy',
#  'jumla',
#  'mogadishu',
#  'stornoway',
#  'chapeco',
#  'kaeo',
#  'viedma',
#  'mbanza-ngungu',
#  'mbaiki',
#  'bereda',
#  'jiexiu',
#  'blatec',
#  'nome',
#  'bafq',
#  'azimur',
#  'khon buri',
#  'sheboygan',
#  'hurghada',
#  'norsup',
#  'inderborskiy',
#  'independence',
#  'peniche',
#  'saint-pierre',
#  'yanan',
#  'zlobin',
#  'saurimo',
#  'ariano irpino',
#  'mehamn',
#  'peleduy',
#  'zhigalovo',
#  'pemangkat',
#  'chanika',
#  'guia lopes da laguna',
#  'neiafu',
#  'baruun-urt',
#  'ayotzintepec',
#  'pandrup',
#  'copiapo',
#  'finnsnes',
#  'sur',
#  'palmer',
#  'namtsy',
#  'talaya',
#  'maniitsoq',
#  'ouadda',
#  'zamosc',
#  'feira nova',
#  'kodino',
#  'waddan',
#  'tairua',
#  'crossfield',
#  'fukue',
#  'te anau',
#  'galle',
#  'erenhot',
#  'gornopravdinsk',
#  'catamarca',
#  'jalu',
#  'ayagoz',
#  'zhanaozen',
#  'krasnyy chikoy',
#  'rorvik',
#  'mabay',
#  'pemberton',
#  'cururupu',
#  'nola',
#  'jaunjelgava',
#  'tazmalt',
#  'kisaran',
#  'twin falls',
#  'tamandare',
#  'caracollo',
#  'igrim',
#  'puerto madryn',
#  'havre-saint-pierre',
#  'dunedin',
#  'bugiri',
#  'ilebo',
#  'mizdah',
#  'skibbereen',
#  'vallenar',
#  'burley',
#  'chapais',
#  'pimenta bueno',
#  'kadykchan',
#  'auburn',
#  'caceres',
#  'fundu moldovei',
#  'conde',
#  'namibe',
#  'pindiga',
#  'tabory',
#  'alugan',
#  'tyukalinsk',
#  'uralets',
#  'plouzane',
#  'gedo',
#  'ust-ilimsk',
#  'talara',
#  'bismil',
#  'karnobat',
#  'vila',
#  'cedar city',
#  'wattegama',
#  'alacranes',
#  'riberalta',
#  'moose factory',
#  'ust-koksa',
#  'nara',
#  'cockburn town',
#  'yago',
#  'sechura',
#  'shingu',
#  'lulea',
#  'krasnoyarsk-66',
#  'tateyama',
#  'nawalapitiya',
#  'chufarovo',
#  'outlook']

# %% [markdown]
# ### Make sure API request works using first city in the list

# %%
# Import API key
import requests

import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")

# %%
city1 = cities[0]
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city.
city1_url = url + "&q=" + city1

# %%
# Make a 'Get' request for the city weather.
city_weather1 = requests.get(city1_url)
city_weather1.json()
# Out:
# {'coord': {'lon': 149.7833, 'lat': -30.3167},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 51.53,
#   'feels_like': 50.23,
#   'temp_min': 51.53,
#   'temp_max': 51.53,
#   'pressure': 1022,
#   'humidity': 82},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 122, 'gust': 11.01},
#  'rain': {'1h': 0.67},
#  'clouds': {'all': 66},
#  'dt': 1658441021,
#  'sys': {'type': 2,
#   'id': 2038202,
#   'country': 'AU',
#   'sunrise': 1658436784,
#   'sunset': 1658474469},
#  'timezone': 36000,
#  'id': 2155742,
#  'name': 'Narrabri',
#  'cod': 200}

# %% [markdown]
# ### Perform API call with OpenWeatherMap

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# # Create an empty list to hold the weather data.
# city_urls = []

# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# # Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes. Use i % 50 mod function.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1
    
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         city_name = city_weather["name"]
#         city_country = city_weather["sys"]["country"]
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_description = city_weather["weather"][0]["description"]
        
#         city_urls.append({"URL": city_url,
#                           "City": city_name,
#                           "Country": city_country,
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Current Description": city_description
#                          })
        
#     # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass
    
    
# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narrabri
# Processing Record 2 of Set 1 | rawson
# Processing Record 3 of Set 1 | pizarro
# Processing Record 4 of Set 1 | ilhabela
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | avera
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | ploemeur
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | hofn
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | la palma
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | tubuala
# Processing Record 25 of Set 1 | idaho falls
# Processing Record 26 of Set 1 | verona
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | caravelas
# Processing Record 29 of Set 1 | raton
# Processing Record 30 of Set 1 | oktyabrskoye
# Processing Record 31 of Set 1 | kungurtug
# Processing Record 32 of Set 1 | huntsville
# Processing Record 33 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 1 | aksu
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | plettenberg bay
# Processing Record 38 of Set 1 | port hardy
# Processing Record 39 of Set 1 | rio cuarto
# Processing Record 40 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 | mindelo
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 1 | tukrah
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | karera
# Processing Record 48 of Set 1 | pochutla
# Processing Record 49 of Set 1 | mapiripan
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | birjand
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | hobyo
# Processing Record 5 of Set 2 | tulagi
# Processing Record 6 of Set 2 | northam
# Processing Record 7 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 2 | muros
# Processing Record 9 of Set 2 | havelock
# Processing Record 10 of Set 2 | olinda
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | vao
# Processing Record 13 of Set 2 | sikonge
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | balkhash
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | merauke
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | digby
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | asyut
# Processing Record 30 of Set 2 | deputatskiy
# Processing Record 31 of Set 2 | san cristobal
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | matara
# Processing Record 34 of Set 2 | suamico
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | bonfim
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | tommot
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 2 | tianpeng
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | san jose
# Processing Record 44 of Set 2 | casino
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | aleksandrov gay
# Processing Record 49 of Set 2 | kralendijk
# Processing Record 50 of Set 2 | margate
# Processing Record 1 of Set 3 | palaikastron
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | wadi maliz
# Processing Record 4 of Set 3 | haines junction
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | tessalit
# Processing Record 7 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 3 | turbat
# Processing Record 9 of Set 3 | tandarei
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | horadiz
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | hami
# Processing Record 21 of Set 3 | jafarpur
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | taoudenni
# Processing Record 24 of Set 3 | grand baie
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | ulladulla
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | natal
# Processing Record 29 of Set 3 | okha
# Processing Record 30 of Set 3 | corinto
# Processing Record 31 of Set 3 | chunskiy
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 3 | sabya
# Processing Record 35 of Set 3 | douglas
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | port townsend
# Processing Record 38 of Set 3 | puerto rico
# Processing Record 39 of Set 3 | tomatlan
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | takoradi
# Processing Record 43 of Set 3 | goure
# Processing Record 44 of Set 3 | dikson
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | sungaipenuh
# Processing Record 47 of Set 3 | rio grande
# Processing Record 48 of Set 3 | charters towers
# Processing Record 49 of Set 3 | det udom
# Processing Record 50 of Set 3 | punta de piedra
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | zhigansk
# Processing Record 3 of Set 4 | ous
# Processing Record 4 of Set 4 | asientos
# Processing Record 5 of Set 4 | zhongshu
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | nabire
# Processing Record 8 of Set 4 | beringovskiy
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | saint anthony
# Processing Record 12 of Set 4 | inongo
# Processing Record 13 of Set 4 | codrington
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | krasnoarmeysk
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | mayskiy
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | aguachica
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | columbus
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | kosonsoy
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | fort nelson
# Processing Record 28 of Set 4 | akonolinga
# Processing Record 29 of Set 4 | cidreira
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | banda aceh
# Processing Record 32 of Set 4 | warmbad
# Processing Record 33 of Set 4 | the valley
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | krasnoselkup
# Processing Record 36 of Set 4 | porto murtinho
# Processing Record 37 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 4 | acarau
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | san pedro
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | ardmore
# Processing Record 44 of Set 4 | sioux lookout
# Processing Record 45 of Set 4 | bogovarovo
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | baraboo
# Processing Record 48 of Set 4 | bonthe
# Processing Record 49 of Set 4 | verkhnevilyuysk
# Processing Record 50 of Set 4 | comodoro rivadavia
# Processing Record 1 of Set 5 | trelew
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | necochea
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | kamenka
# Processing Record 8 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | nizhniy kuranakh
# Processing Record 11 of Set 5 | anadyr
# Processing Record 12 of Set 5 | joshimath
# Processing Record 13 of Set 5 | gat
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | krapivinskiy
# Processing Record 16 of Set 5 | lavrentiya
# Processing Record 17 of Set 5 | tambopata
# Processing Record 18 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 5 | netivot
# Processing Record 20 of Set 5 | tazovskiy
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 5 | ilulissat
# Processing Record 25 of Set 5 | pasni
# Processing Record 26 of Set 5 | west wendover
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | mancio lima
# Processing Record 29 of Set 5 | nantucket
# Processing Record 30 of Set 5 | lahij
# Processing Record 31 of Set 5 | salamiyah
# Processing Record 32 of Set 5 | narasannapeta
# Processing Record 33 of Set 5 | hannan
# Processing Record 34 of Set 5 | mecca
# Processing Record 35 of Set 5 | cazaje
# City not found. Skipping...
# Processing Record 36 of Set 5 | witney
# Processing Record 37 of Set 5 | yenagoa
# Processing Record 38 of Set 5 | zheleznodorozhnyy
# Processing Record 39 of Set 5 | kyabram
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 5 | mayo
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | kropotkin
# Processing Record 45 of Set 5 | riyadh
# Processing Record 46 of Set 5 | birao
# Processing Record 47 of Set 5 | aguimes
# Processing Record 48 of Set 5 | kedougou
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | fortuna
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | awjilah
# Processing Record 3 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | port moresby
# Processing Record 7 of Set 6 | wanning
# Processing Record 8 of Set 6 | marzuq
# Processing Record 9 of Set 6 | moengo
# Processing Record 10 of Set 6 | ust-nera
# Processing Record 11 of Set 6 | bridgetown
# Processing Record 12 of Set 6 | kodinsk
# Processing Record 13 of Set 6 | mannarakkat
# Processing Record 14 of Set 6 | el tigre
# Processing Record 15 of Set 6 | luba
# Processing Record 16 of Set 6 | port hedland
# Processing Record 17 of Set 6 | strezhevoy
# Processing Record 18 of Set 6 | kupang
# Processing Record 19 of Set 6 | iquitos
# Processing Record 20 of Set 6 | shkotovo-26
# City not found. Skipping...
# Processing Record 21 of Set 6 | leninskoye
# Processing Record 22 of Set 6 | akyab
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 6 | oistins
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | santiago del estero
# Processing Record 29 of Set 6 | dezful
# Processing Record 30 of Set 6 | kuruman
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | faanui
# Processing Record 33 of Set 6 | montego bay
# Processing Record 34 of Set 6 | muravlenko
# Processing Record 35 of Set 6 | nhulunbuy
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | nuevo progreso
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | veseloyarsk
# Processing Record 42 of Set 6 | paoua
# Processing Record 43 of Set 6 | nikolskoye
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | mantua
# Processing Record 46 of Set 6 | graciano sanchez
# Processing Record 47 of Set 6 | huaidian
# Processing Record 48 of Set 6 | komsomolskiy
# Processing Record 49 of Set 6 | wencheng
# Processing Record 50 of Set 6 | tasiilaq
# Processing Record 1 of Set 7 | new castle
# Processing Record 2 of Set 7 | khromtau
# Processing Record 3 of Set 7 | darhan
# Processing Record 4 of Set 7 | priiskovyy
# Processing Record 5 of Set 7 | arinos
# Processing Record 6 of Set 7 | diffa
# Processing Record 7 of Set 7 | yulara
# Processing Record 8 of Set 7 | sailana
# Processing Record 9 of Set 7 | fairbanks
# Processing Record 10 of Set 7 | luena
# Processing Record 11 of Set 7 | santa isabel do rio negro
# Processing Record 12 of Set 7 | guerrero negro
# Processing Record 13 of Set 7 | lagoa
# Processing Record 14 of Set 7 | bud
# Processing Record 15 of Set 7 | new delhi
# Processing Record 16 of Set 7 | leningradskiy
# Processing Record 17 of Set 7 | susanville
# Processing Record 18 of Set 7 | gunjur
# Processing Record 19 of Set 7 | ambilobe
# Processing Record 20 of Set 7 | makokou
# Processing Record 21 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 7 | ukiah
# Processing Record 23 of Set 7 | padang
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | zaozerne
# Processing Record 26 of Set 7 | muli
# Processing Record 27 of Set 7 | toora-khem
# Processing Record 28 of Set 7 | ocampo
# Processing Record 29 of Set 7 | new norfolk
# Processing Record 30 of Set 7 | lixourion
# Processing Record 31 of Set 7 | muswellbrook
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | karoi
# Processing Record 34 of Set 7 | tigil
# Processing Record 35 of Set 7 | pendleton
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | dwarka
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | gabu
# Processing Record 41 of Set 7 | walvis bay
# Processing Record 42 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 43 of Set 7 | batagay
# Processing Record 44 of Set 7 | kushima
# Processing Record 45 of Set 7 | andenes
# Processing Record 46 of Set 7 | tir pol
# City not found. Skipping...
# Processing Record 47 of Set 7 | kinablangan
# Processing Record 48 of Set 7 | bambanglipuro
# Processing Record 49 of Set 7 | mizque
# Processing Record 50 of Set 7 | kruisfontein
# Processing Record 1 of Set 8 | southbridge
# Processing Record 2 of Set 8 | kedrovyy
# Processing Record 3 of Set 8 | shieli
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | brae
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | victoria
# Processing Record 8 of Set 8 | lalmohan
# Processing Record 9 of Set 8 | turayf
# Processing Record 10 of Set 8 | dapaong
# Processing Record 11 of Set 8 | songjianghe
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | lafia
# Processing Record 14 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 8 | linqing
# Processing Record 16 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 8 | ranong
# Processing Record 18 of Set 8 | chongoyape
# Processing Record 19 of Set 8 | khor
# Processing Record 20 of Set 8 | auki
# Processing Record 21 of Set 8 | constantine
# Processing Record 22 of Set 8 | namatanai
# Processing Record 23 of Set 8 | hurricane
# Processing Record 24 of Set 8 | soe
# Processing Record 25 of Set 8 | havoysund
# Processing Record 26 of Set 8 | barcelos
# Processing Record 27 of Set 8 | evensk
# Processing Record 28 of Set 8 | sarangani
# Processing Record 29 of Set 8 | udgir
# Processing Record 30 of Set 8 | ponta delgada
# Processing Record 31 of Set 8 | quang ngai
# Processing Record 32 of Set 8 | shenjiamen
# Processing Record 33 of Set 8 | alvdal
# Processing Record 34 of Set 8 | maltahohe
# Processing Record 35 of Set 8 | mwene-ditu
# Processing Record 36 of Set 8 | camopi
# Processing Record 37 of Set 8 | hovd
# Processing Record 38 of Set 8 | gushikawa
# Processing Record 39 of Set 8 | pala
# Processing Record 40 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 8 | baymak
# Processing Record 42 of Set 8 | santa cruz
# Processing Record 43 of Set 8 | shevchenkove
# Processing Record 44 of Set 8 | xining
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | kota bahru
# Processing Record 47 of Set 8 | santa maria
# Processing Record 48 of Set 8 | naze
# Processing Record 49 of Set 8 | kamaishi
# Processing Record 50 of Set 8 | black river
# Processing Record 1 of Set 9 | henties bay
# Processing Record 2 of Set 9 | kolosovka
# Processing Record 3 of Set 9 | yichang
# Processing Record 4 of Set 9 | coruripe
# Processing Record 5 of Set 9 | opuwo
# Processing Record 6 of Set 9 | santa fe
# Processing Record 7 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 8 of Set 9 | alasehir
# Processing Record 9 of Set 9 | tagab
# Processing Record 10 of Set 9 | suileng
# Processing Record 11 of Set 9 | makakilo city
# Processing Record 12 of Set 9 | burgeo
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | belawan
# Processing Record 15 of Set 9 | esperance
# Processing Record 16 of Set 9 | sharanga
# Processing Record 17 of Set 9 | coari
# Processing Record 18 of Set 9 | sambava
# Processing Record 19 of Set 9 | grand gaube
# Processing Record 20 of Set 9 | garissa
# Processing Record 21 of Set 9 | provideniya
# Processing Record 22 of Set 9 | uvalde
# Processing Record 23 of Set 9 | esna
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | bealanana
# Processing Record 26 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 9 | salinas
# Processing Record 29 of Set 9 | half moon bay
# Processing Record 30 of Set 9 | sosnovo-ozerskoye
# Processing Record 31 of Set 9 | tovuz
# Processing Record 32 of Set 9 | namanga
# Processing Record 33 of Set 9 | berbera
# Processing Record 34 of Set 9 | olafsvik
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | iranshahr
# Processing Record 37 of Set 9 | linhares
# Processing Record 38 of Set 9 | monroe
# Processing Record 39 of Set 9 | bonavista
# Processing Record 40 of Set 9 | college
# Processing Record 41 of Set 9 | holme
# Processing Record 42 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 9 | kosh-agach
# Processing Record 44 of Set 9 | sakakah
# Processing Record 45 of Set 9 | varberg
# Processing Record 46 of Set 9 | dong hoi
# Processing Record 47 of Set 9 | luebo
# Processing Record 48 of Set 9 | maceio
# Processing Record 49 of Set 9 | argir
# Processing Record 50 of Set 9 | nyurba
# Processing Record 1 of Set 10 | svetlogorsk
# Processing Record 2 of Set 10 | karasburg
# Processing Record 3 of Set 10 | ust-tsilma
# Processing Record 4 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 10 | ayan
# Processing Record 6 of Set 10 | aiyira
# Processing Record 7 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 10 | saint-paul
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | meulaboh
# Processing Record 11 of Set 10 | pacific grove
# Processing Record 12 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | ullapool
# Processing Record 15 of Set 10 | ariquemes
# Processing Record 16 of Set 10 | kloulklubed
# Processing Record 17 of Set 10 | kokopo
# Processing Record 18 of Set 10 | east london
# Processing Record 19 of Set 10 | boende
# Processing Record 20 of Set 10 | faya
# Processing Record 21 of Set 10 | la ronge
# Processing Record 22 of Set 10 | labuhan
# Processing Record 23 of Set 10 | bat khela
# Processing Record 24 of Set 10 | raudeberg
# Processing Record 25 of Set 10 | neyshabur
# Processing Record 26 of Set 10 | esmeraldas
# Processing Record 27 of Set 10 | praya
# Processing Record 28 of Set 10 | sorland
# Processing Record 29 of Set 10 | nicolas bravo
# Processing Record 30 of Set 10 | acapulco
# Processing Record 31 of Set 10 | shimoda
# Processing Record 32 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 34 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 35 of Set 10 | bayshore gardens
# Processing Record 36 of Set 10 | mildura
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | maun
# Processing Record 39 of Set 10 | ondjiva
# Processing Record 40 of Set 10 | teguise
# Processing Record 41 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 10 | olean
# Processing Record 43 of Set 10 | taraz
# Processing Record 44 of Set 10 | kuryk
# Processing Record 45 of Set 10 | mackay
# Processing Record 46 of Set 10 | brigantine
# Processing Record 47 of Set 10 | geraldton
# Processing Record 48 of Set 10 | panzhihua
# Processing Record 49 of Set 10 | bathsheba
# Processing Record 50 of Set 10 | cervo
# Processing Record 1 of Set 11 | brownfield
# Processing Record 2 of Set 11 | rosarito
# Processing Record 3 of Set 11 | arlit
# Processing Record 4 of Set 11 | ducheng
# Processing Record 5 of Set 11 | dakar
# Processing Record 6 of Set 11 | herat
# Processing Record 7 of Set 11 | chittaurgarh
# Processing Record 8 of Set 11 | donskoye
# Processing Record 9 of Set 11 | santo tomas
# Processing Record 10 of Set 11 | thinadhoo
# Processing Record 11 of Set 11 | korla
# Processing Record 12 of Set 11 | husavik
# Processing Record 13 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | yatou
# Processing Record 15 of Set 11 | campiglia marittima
# Processing Record 16 of Set 11 | baykit
# Processing Record 17 of Set 11 | khonsa
# Processing Record 18 of Set 11 | arona
# Processing Record 19 of Set 11 | panlaitan
# Processing Record 20 of Set 11 | belmonte
# Processing Record 21 of Set 11 | sorong
# Processing Record 22 of Set 11 | sitka
# Processing Record 23 of Set 11 | rock sound
# Processing Record 24 of Set 11 | bay roberts
# Processing Record 25 of Set 11 | matagami
# Processing Record 26 of Set 11 | tautira
# Processing Record 27 of Set 11 | grindavik
# Processing Record 28 of Set 11 | can tho
# Processing Record 29 of Set 11 | egvekinot
# Processing Record 30 of Set 11 | shubarkuduk
# Processing Record 31 of Set 11 | meadow lake
# Processing Record 32 of Set 11 | binga
# Processing Record 33 of Set 11 | rockland
# Processing Record 34 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 11 | domoni
# Processing Record 36 of Set 11 | carauari
# Processing Record 37 of Set 11 | asau
# Processing Record 38 of Set 11 | pangnirtung
# Processing Record 39 of Set 11 | trojan
# Processing Record 40 of Set 11 | watsa
# Processing Record 41 of Set 11 | ngunguru
# Processing Record 42 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 43 of Set 11 | stutterheim
# Processing Record 44 of Set 11 | hwange
# Processing Record 45 of Set 11 | mangaratiba
# Processing Record 46 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 11 | karlshamn
# Processing Record 48 of Set 11 | san patricio
# Processing Record 49 of Set 11 | impfondo
# Processing Record 50 of Set 11 | hvide sande
# Processing Record 1 of Set 12 | akdepe
# Processing Record 2 of Set 12 | kapit
# Processing Record 3 of Set 12 | kyren
# Processing Record 4 of Set 12 | biograd na moru
# Processing Record 5 of Set 12 | yurla
# Processing Record 6 of Set 12 | hammerfest
# Processing Record 7 of Set 12 | kalabo
# Processing Record 8 of Set 12 | bandarbeyla
# Processing Record 9 of Set 12 | ahuimanu
# Processing Record 10 of Set 12 | ewa beach
# Processing Record 11 of Set 12 | basco
# Processing Record 12 of Set 12 | lynn haven
# Processing Record 13 of Set 12 | hamilton
# Processing Record 14 of Set 12 | ahipara
# Processing Record 15 of Set 12 | ushtobe
# Processing Record 16 of Set 12 | port-cartier
# Processing Record 17 of Set 12 | doha
# Processing Record 18 of Set 12 | coracora
# Processing Record 19 of Set 12 | saint-joseph
# Processing Record 20 of Set 12 | sarankhola
# Processing Record 21 of Set 12 | bakchar
# Processing Record 22 of Set 12 | borzya
# Processing Record 23 of Set 12 | bertoua
# Processing Record 24 of Set 12 | manacapuru
# Processing Record 25 of Set 12 | puerto varas
# Processing Record 26 of Set 12 | yeppoon
# Processing Record 27 of Set 12 | mocuba
# Processing Record 28 of Set 12 | bulgan
# Processing Record 29 of Set 12 | buala
# Processing Record 30 of Set 12 | lexington
# Processing Record 31 of Set 12 | los lunas
# Processing Record 32 of Set 12 | hambantota
# Processing Record 33 of Set 12 | ulkan
# Processing Record 34 of Set 12 | maumere
# Processing Record 35 of Set 12 | eureka
# Processing Record 36 of Set 12 | yazman
# Processing Record 37 of Set 12 | vila velha
# Processing Record 38 of Set 12 | lunglei
# Processing Record 39 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 12 | sao joao da barra
# Processing Record 41 of Set 12 | vestmannaeyjar
# Processing Record 42 of Set 12 | nizhniy odes
# Processing Record 43 of Set 12 | kohima
# Processing Record 44 of Set 12 | itamaraca
# Processing Record 45 of Set 12 | mountain home
# Processing Record 46 of Set 12 | hauterive
# Processing Record 47 of Set 12 | ribas do rio pardo
# Processing Record 48 of Set 12 | chengde
# Processing Record 49 of Set 12 | nampula
# Processing Record 50 of Set 12 | araouane
# Processing Record 1 of Set 13 | kudahuvadhoo
# Processing Record 2 of Set 13 | kitimat
# Processing Record 3 of Set 13 | mnogovershinnyy
# Processing Record 4 of Set 13 | toamasina
# Processing Record 5 of Set 13 | babino
# Processing Record 6 of Set 13 | beaverlodge
# Processing Record 7 of Set 13 | vostok
# Processing Record 8 of Set 13 | ternuvate
# Processing Record 9 of Set 13 | cap malheureux
# Processing Record 10 of Set 13 | najran
# Processing Record 11 of Set 13 | tibati
# Processing Record 12 of Set 13 | isangel
# Processing Record 13 of Set 13 | bara
# Processing Record 14 of Set 13 | tarazona
# Processing Record 15 of Set 13 | dalby
# Processing Record 16 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 13 | marfino
# Processing Record 18 of Set 13 | nizhniy ingash
# Processing Record 19 of Set 13 | lure
# Processing Record 20 of Set 13 | marsa matruh
# Processing Record 21 of Set 13 | coihaique
# Processing Record 22 of Set 13 | banganapalle
# Processing Record 23 of Set 13 | samarai
# Processing Record 24 of Set 13 | severnoye
# Processing Record 25 of Set 13 | kharp
# Processing Record 26 of Set 13 | itarema
# Processing Record 27 of Set 13 | altamira
# Processing Record 28 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 13 | dongsheng
# Processing Record 30 of Set 13 | cento
# Processing Record 31 of Set 13 | broome
# Processing Record 32 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 13 | katsuura
# Processing Record 34 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 13 | brownsville
# Processing Record 36 of Set 13 | urubicha
# Processing Record 37 of Set 13 | megion
# Processing Record 38 of Set 13 | shirokiy
# Processing Record 39 of Set 13 | jumla
# Processing Record 40 of Set 13 | mogadishu
# Processing Record 41 of Set 13 | stornoway
# Processing Record 42 of Set 13 | chapeco
# Processing Record 43 of Set 13 | kaeo
# Processing Record 44 of Set 13 | viedma
# Processing Record 45 of Set 13 | mbanza-ngungu
# Processing Record 46 of Set 13 | mbaiki
# Processing Record 47 of Set 13 | bereda
# Processing Record 48 of Set 13 | jiexiu
# Processing Record 49 of Set 13 | blatec
# Processing Record 50 of Set 13 | nome
# Processing Record 1 of Set 14 | bafq
# Processing Record 2 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 3 of Set 14 | khon buri
# Processing Record 4 of Set 14 | sheboygan
# Processing Record 5 of Set 14 | hurghada
# Processing Record 6 of Set 14 | norsup
# Processing Record 7 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 14 | independence
# Processing Record 9 of Set 14 | peniche
# Processing Record 10 of Set 14 | saint-pierre
# Processing Record 11 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 14 | zlobin
# Processing Record 13 of Set 14 | saurimo
# Processing Record 14 of Set 14 | ariano irpino
# Processing Record 15 of Set 14 | mehamn
# Processing Record 16 of Set 14 | peleduy
# Processing Record 17 of Set 14 | zhigalovo
# Processing Record 18 of Set 14 | pemangkat
# Processing Record 19 of Set 14 | chanika
# Processing Record 20 of Set 14 | guia lopes da laguna
# Processing Record 21 of Set 14 | neiafu
# Processing Record 22 of Set 14 | baruun-urt
# Processing Record 23 of Set 14 | ayotzintepec
# Processing Record 24 of Set 14 | pandrup
# Processing Record 25 of Set 14 | copiapo
# Processing Record 26 of Set 14 | finnsnes
# Processing Record 27 of Set 14 | sur
# Processing Record 28 of Set 14 | palmer
# Processing Record 29 of Set 14 | namtsy
# Processing Record 30 of Set 14 | talaya
# Processing Record 31 of Set 14 | maniitsoq
# Processing Record 32 of Set 14 | ouadda
# Processing Record 33 of Set 14 | zamosc
# Processing Record 34 of Set 14 | feira nova
# Processing Record 35 of Set 14 | kodino
# Processing Record 36 of Set 14 | waddan
# Processing Record 37 of Set 14 | tairua
# Processing Record 38 of Set 14 | crossfield
# Processing Record 39 of Set 14 | fukue
# Processing Record 40 of Set 14 | te anau
# Processing Record 41 of Set 14 | galle
# Processing Record 42 of Set 14 | erenhot
# Processing Record 43 of Set 14 | gornopravdinsk
# Processing Record 44 of Set 14 | catamarca
# Processing Record 45 of Set 14 | jalu
# Processing Record 46 of Set 14 | ayagoz
# Processing Record 47 of Set 14 | zhanaozen
# Processing Record 48 of Set 14 | krasnyy chikoy
# Processing Record 49 of Set 14 | rorvik
# Processing Record 50 of Set 14 | mabay
# Processing Record 1 of Set 15 | pemberton
# Processing Record 2 of Set 15 | cururupu
# Processing Record 3 of Set 15 | nola
# Processing Record 4 of Set 15 | jaunjelgava
# Processing Record 5 of Set 15 | tazmalt
# Processing Record 6 of Set 15 | kisaran
# Processing Record 7 of Set 15 | twin falls
# Processing Record 8 of Set 15 | tamandare
# Processing Record 9 of Set 15 | caracollo
# Processing Record 10 of Set 15 | igrim
# Processing Record 11 of Set 15 | puerto madryn
# Processing Record 12 of Set 15 | havre-saint-pierre
# Processing Record 13 of Set 15 | dunedin
# Processing Record 14 of Set 15 | bugiri
# Processing Record 15 of Set 15 | ilebo
# Processing Record 16 of Set 15 | mizdah
# Processing Record 17 of Set 15 | skibbereen
# Processing Record 18 of Set 15 | vallenar
# Processing Record 19 of Set 15 | burley
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | pimenta bueno
# Processing Record 22 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 15 | auburn
# Processing Record 24 of Set 15 | caceres
# Processing Record 25 of Set 15 | fundu moldovei
# Processing Record 26 of Set 15 | conde
# Processing Record 27 of Set 15 | namibe
# Processing Record 28 of Set 15 | pindiga
# Processing Record 29 of Set 15 | tabory
# Processing Record 30 of Set 15 | alugan
# Processing Record 31 of Set 15 | tyukalinsk
# Processing Record 32 of Set 15 | uralets
# Processing Record 33 of Set 15 | plouzane
# Processing Record 34 of Set 15 | gedo
# Processing Record 35 of Set 15 | ust-ilimsk
# Processing Record 36 of Set 15 | talara
# Processing Record 37 of Set 15 | bismil
# Processing Record 38 of Set 15 | karnobat
# Processing Record 39 of Set 15 | vila
# Processing Record 40 of Set 15 | cedar city
# Processing Record 41 of Set 15 | wattegama
# Processing Record 42 of Set 15 | alacranes
# Processing Record 43 of Set 15 | riberalta
# Processing Record 44 of Set 15 | moose factory
# Processing Record 45 of Set 15 | ust-koksa
# Processing Record 46 of Set 15 | nara
# Processing Record 47 of Set 15 | cockburn town
# Processing Record 48 of Set 15 | yago
# Processing Record 49 of Set 15 | sechura
# Processing Record 50 of Set 15 | shingu
# Processing Record 1 of Set 16 | lulea
# Processing Record 2 of Set 16 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 3 of Set 16 | tateyama
# Processing Record 4 of Set 16 | nawalapitiya
# Processing Record 5 of Set 16 | chufarovo
# Processing Record 6 of Set 16 | outlook
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 2 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 3 of Set 1 | khatima
# City not found. Skipping...
# Processing Record 4 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 5 of Set 1 | ahipara
# City not found. Skipping...
# Processing Record 6 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 7 of Set 1 | rio grande
# City not found. Skipping...
# Processing Record 8 of Set 1 | rabo de peixe
# City not found. Skipping...
# Processing Record 9 of Set 1 | ust-nera
# City not found. Skipping...
# Processing Record 10 of Set 1 | batemans bay
# City not found. Skipping...
# Processing Record 11 of Set 1 | kaitangata
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 13 of Set 1 | umm lajj
# City not found. Skipping...
# Processing Record 14 of Set 1 | nueve de julio
# City not found. Skipping...
# Processing Record 15 of Set 1 | launceston
# City not found. Skipping...
# Processing Record 16 of Set 1 | pevek
# City not found. Skipping...
# Processing Record 17 of Set 1 | tigil
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 19 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 20 of Set 1 | rumuruti
# City not found. Skipping...
# Processing Record 21 of Set 1 | flinders
# City not found. Skipping...
# Processing Record 22 of Set 1 | tiarei
# City not found. Skipping...
# Processing Record 23 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 24 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 25 of Set 1 | stornoway
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 27 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 28 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 29 of Set 1 | magadan
# City not found. Skipping...
# Processing Record 30 of Set 1 | alugan
# City not found. Skipping...
# Processing Record 31 of Set 1 | los llanos de aridane
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 34 of Set 1 | kahului
# City not found. Skipping...
# Processing Record 35 of Set 1 | santa rosalia
# City not found. Skipping...
# Processing Record 36 of Set 1 | coahuayana
# City not found. Skipping...
# Processing Record 37 of Set 1 | houma
# City not found. Skipping...
# Processing Record 38 of Set 1 | krasnoselkup
# City not found. Skipping...
# Processing Record 39 of Set 1 | lagoa
# City not found. Skipping...
# Processing Record 40 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 41 of Set 1 | marquette
# City not found. Skipping...
# Processing Record 42 of Set 1 | fallon
# City not found. Skipping...
# Processing Record 43 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 44 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 1 | partizanske
# City not found. Skipping...
# Processing Record 46 of Set 1 | port lincoln
# City not found. Skipping...
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | znamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 1 | komsomolskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...

# %%
# len(city_urls)
# Out:
# 696

# %%
# # Convert the array of dictionaries to a Pandas DataFrame.

# city_data_df = pd.DataFrame(city_urls)
# city_data_df = city_data_df.drop(["URL"], axis=1)
# city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Narrabri      AU -30.3167  149.7833     54.52        78          70
# 1          Rawson      AR -43.3002  -65.1023     44.91        52         100
# 2         Pizarro      CO   4.9533  -77.3660     77.07        89          97
# 3        Ilhabela      BR -23.7781  -45.3581     68.13        91          42
# 4         Ushuaia      AR -54.8000  -68.3000     29.86        93          75
# ..            ...     ...      ...       ...       ...       ...         ...
# 691         Luleå      SE  65.5842   22.1547     62.67       100         100
# 692      Tateyama      JP  34.9833  139.8667     82.33        88          21
# 693  Nawalapitiya      LK   7.0559   80.5348     70.29        99         100
# 694     Chufarovo      RU  54.0963   47.3367     60.08        93          96
# 695       Outlook      CA  51.5001 -107.0513     83.23        32          53
#
#      Wind Speed Current Description
# 0          5.01       broken clouds
# 1         12.97     overcast clouds
# 2          5.41          light rain
# 3          7.58    scattered clouds
# 4         19.57                snow
# ..          ...                 ...
# 691        4.61     overcast clouds
# 692       15.70          few clouds
# 693        2.55     overcast clouds
# 694       10.69     overcast clouds
# 695       17.87       broken clouds
#
# [696 rows x 9 columns]

# %%
# # Save DataFrame to output file
# output_data_file = "WeatherPy_Database.csv"

# #Export the city_data_df to a csv.
# city_data_df.to_csv(output_data_file)
